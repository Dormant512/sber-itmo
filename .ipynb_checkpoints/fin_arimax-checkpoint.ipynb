# %% [markdown]
# # ARIMAX on client + exogenous context info

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
#sns.set(font='IPAGothic')

from datetime import date, timedelta, datetime
import numpy as np
import statsmodels.api as sm
import statsmodels.tsa.api as smt

import itertools

# %%
from colour import Color

plt.rcParams['figure.figsize'] = [15, 7.5]
plt.rcParams['font.size'] = 18
#plt.style.use('dark_background')

orange = Color("orange")

color_objs = list(orange.range_to(Color("slateblue"), 14))
colors = [col.hex for col in color_objs]
len(colors)
# Out:
# 14

# %% [markdown]
# ### Read datasets

# %%
basedate = date(2020, 1, 1)

deltify = lambda x: (x - basedate).days

# %%
npzfile0 = np.load('./sber_work_files/final/synt_clients_w_gr_names_ver2.npz', allow_pickle=True)

client_df = npzfile0['client_df']
group_names = npzfile0['group_names']

# %%
cli_dfs = []
for num in range(len(group_names)):
    cli_data = client_df[:,num,:].T
    cli_df = pd.DataFrame(data=cli_data[0:,0:], \
                         index=[basedate + timedelta(i) for i in range(cli_data.shape[0])], \
                         columns=[f"c{i}" for i in range(cli_data.shape[1])])

    cli_df = cli_df.sum(axis=1)
    cli_df = cli_df.asfreq('d')

    cli_trend = sm.tsa.seasonal_decompose(cli_df, model='additive').trend
    cli_dfs.append(cli_trend)

# %%
plt.figure(facecolor='white')
cli_dfs[0].plot()
plt.xlabel('Date')
plt.ylabel('Spendings, rub')
plt.title(f"{group_names[0]} raw")
# Out:
# Text(0.5, 1.0, 'food raw')

# %% [markdown]
# Remove everything before April, 1st, as if:
#
# ```basedate = date(2020, 4, 1)```

# %%
for i in range(len(cli_dfs)):
    cli_dfs[i] = cli_dfs[i][cli_dfs[i].index.date >= date(2020, 4, 1)]

plt.figure(facecolor='white')
cli_dfs[0].plot()
plt.xlabel('Date')
plt.ylabel('Spendings, rub')
plt.title(f"{group_names[0]} truncated")
# Out:
# Text(0.5, 1.0, 'food truncated')

# %%
for num, item in enumerate(cli_dfs):
    res_diff = item.diff().dropna()
    result = smt.stattools.adfuller(res_diff)
    print(f"\nVariable diffed once: {group_names[num]}")
    print("Augmented Dickey-Fuller test:")
    print(f"\tStatistic value = {result[0]:.5f}\n\tp-value = {result[1]:.5f}")
    print(f"\tCrit 5%: {result[4]['5%']:.5f}")
    print("\tStationary" if (result[1] < 0.05) and \
          (result[0] < result[4]['5%']) else "\tNon-stationary")
# Out:
# Variable diffed once: food
# Augmented Dickey-Fuller test:
# 	Statistic value = -4.03535
# 	p-value = 0.00124
# 	Crit 5%: -2.87933
# 	Stationary
#
# Variable diffed once: nonfood
# Augmented Dickey-Fuller test:
# 	Statistic value = -3.09705
# 	p-value = 0.02677
# 	Crit 5%: -2.87933
# 	Stationary
#
# Variable diffed once: travel
# Augmented Dickey-Fuller test:
# 	Statistic value = -3.52043
# 	p-value = 0.00748
# 	Crit 5%: -2.87933
# 	Stationary
#
# Variable diffed once: money
# Augmented Dickey-Fuller test:
# 	Statistic value = -5.74402
# 	p-value = 0.00000
# 	Crit 5%: -2.87922
# 	Stationary
#
# Variable diffed once: beauty
# Augmented Dickey-Fuller test:
# 	Statistic value = -4.40901
# 	p-value = 0.00029
# 	Crit 5%: -2.87922
# 	Stationary
#
# Variable diffed once: fun
# Augmented Dickey-Fuller test:
# 	Statistic value = -4.21281
# 	p-value = 0.00063
# 	Crit 5%: -2.87933
# 	Stationary
#
# Variable diffed once: health
# Augmented Dickey-Fuller test:
# 	Statistic value = -5.32667
# ...

# %%
basedate_test = date(2020, 9, 10)

# %% [markdown]
# ### Set up news

# %%
npzfile1 = np.load('./sber_work_files/final/news4work.npz', allow_pickle=True)

month_ticks = npzfile1['month_ticks']
month_names = npzfile1['month_names']
fin_top_ts = npzfile1['fin_top_ts']
fin_top_names = npzfile1['fin_top_names']
sorted_topic_names_dict = npzfile1['sorted_topic_names_dict']

# %%
npzfile2 = np.load('./sber_work_files/final/context_w_labels.npz', allow_pickle=True)

context_ts = npzfile2['context_ts']
context_labels = npzfile2['context_labels']

# %%
context_names = list(fin_top_names) + list(context_labels)
print(context_names)
# Out:
# ['Ковид', 'Белоруссия', 'Украина', 'Здоровье', 'Спорт', 'Погода', 'Религия', 'Авиация', 'Путешествия', 'Метро', 'Телевидение', 'Инвестиции', 'Правительство', 'Индекс доступности недвижимости, СПБ', 'Индекс доступности недвижимости, Россия', 'Ключевая ставка ЦБ', 'Инфляция в процентах годовых', 'Курс доллара, руб', 'Средние ставки по ипотеке', 'Средние ставки по ипотеке, перв. рынок', 'Средние ставки по ипотеке, втор. рынок', 'Индекс потребительских цен', 'Индекс потребительских цен, продовольствие', 'Индекс потребительских цен, не продукты', 'Индекс потребительских цен, услуги', 'Безработица', 'ВВП относительно предыдущего года', 'Относительный ВВП за вычетом сезонных вкладов', 'ВВП в млрд. руб.', 'Covid-19 в РФ, всего заражений', 'Covid-19 в РФ, новых заражений', 'Covid-19 в РФ, всего смертей', 'Covid-19 в РФ, новых смертей']

# %%
news_data = np.concatenate((fin_top_ts, context_ts), axis=0).T
print(news_data.shape)

news_df = pd.DataFrame(data=news_data[0:,0:], \
                     index=[basedate + timedelta(i) for i in range(news_data.shape[0])], \
                     columns=[context_names[i] for i in range(news_data.shape[1])])

news_df = news_df.fillna(0).asfreq('d')
news_df = news_df[news_df.index.date >= date(2020, 4, 1)]
news_df.head()
# Out:
# (274, 33)
#                  Ковид  Белоруссия    Украина   Здоровье      Спорт    Погода  \
# 2020-04-01  100.000000    1.000000  23.000000  21.000000  13.000000  8.000000
# 2020-04-02  100.540597    0.967494  22.814290  21.117951  12.790381  8.212381
# 2020-04-03  101.644700    0.971187  22.713299  21.275552  12.469273  8.329720
# 2020-04-04  103.312308    1.011079  22.697024  21.472801  12.036677  8.352016
# 2020-04-05  105.469589    1.087170  22.755690  21.696265  11.529503  8.289662
#
#              Религия    Авиация  Путешествия      Метро  ...  \
# 2020-04-01  2.000000  16.000000    17.000000  21.000000  ...
# 2020-04-02  1.741896  16.916354    16.636212  19.022325  ...
# 2020-04-03  2.107478  17.768783    15.508165  16.885313  ...
# 2020-04-04  3.096747  18.557287    13.615858  14.588965  ...
# 2020-04-05  4.642546  19.239580    11.114311  12.218786  ...
#
#             Индекс потребительских цен, не продукты  \
# 2020-04-01                               100.440000
# ...

# %%
arimax_skipped = True
num_experiments = 10

# %% [markdown]
# # ARIMAX (if done, go to CHECKPOINT)

# %%
arimax_skipped = False
plot = False

rrmse_matrix = np.zeros((len(group_names), len(context_names), num_experiments))

for add_exp in range(num_experiments):
    start_test = basedate_test + timedelta(add_exp)
    for num_gr in range(len(group_names)):
        cli_df = cli_dfs[num_gr]
        cli_test = cli_df[cli_df.index.date >= start_test].copy()
        cli_train = cli_df[cli_df.index.date < start_test].copy()

        for topic_num, topic_name in enumerate(context_names):
            news_cur = news_df[str(topic_name)]
            news_test = news_cur[news_cur.index.date >= start_test].copy()
            news_train = news_cur[news_cur.index.date < start_test].copy()

            arimax = sm.tsa.statespace.SARIMAX(cli_train, \
                                            order=(7,1,7), \
                                            seasonal_order=(0,0,0,0), \
                                            exog = news_train, \
                                            freq='D', \
                                            enforce_stationarity=False, \
                                            enforce_invertibility=False).fit(disp=False)
            pred = arimax.predict(start_test, date(2020, 9, 30), exog=news_test)[1:]
        
            #print(f"Group {num_gr} Context {topic_name}")
        
            cur_pred = pd.DataFrame([pred, cli_test]).T.dropna()
            arr1 = (np.array(cur_pred['predicted_mean']) - np.array(cur_pred['trend']))**2
            arr2 = np.array(cur_pred['trend']).mean()
            rrmse = np.sqrt(arr1.sum()/(len(cur_pred) - 1)) / arr2
            #print(arr1, arr2, rrmse)
            rrmse_matrix[num_gr, topic_num, add_exp] = rrmse
            print(f"{num_gr * len(context_names) + topic_num + 1} / {len(context_names) * len(group_names)}")
    
            if plot:
                plt.clf()
                plt.plot(cli_df)
                plt.plot(pred)
                plt.title(f"Category: {group_names[num_gr]}    Context: {topic_name}")
                plt.ylabel("Spendings, rub")
                plt.xlabel("Date")
                plt.legend(["Real", "Predicted"])
                plt.savefig(f"./arimax_pics/{group_names[num_gr]}/{topic_name}.png")
# Out:
# 1 / 462
# 2 / 462
# 3 / 462
# /home/dormant/.local/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 4 / 462
# 5 / 462
# 6 / 462
# 7 / 462
# 8 / 462
# 9 / 462
# 10 / 462
# 11 / 462
# 12 / 462
# 13 / 462
# 14 / 462
# /home/dormant/.local/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 15 / 462
# 16 / 462
# 17 / 462
# 18 / 462
# 19 / 462
# 20 / 462
# 21 / 462
# /home/dormant/.local/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 22 / 462
# 23 / 462
# ...

# %%
print(rrmse_matrix.T.shape)
rrmse_matrix = np.sum(rrmse_matrix.T, axis=0)
print(rrmse_matrix.shape)
# Out:
# (10, 33, 14)
# (33, 14)

# %%
print(str(basedate_test))
print(str(start_test))
# Out:
# 2020-09-10
# 2020-09-19

# %%
import csv

with open(f'rrmse_matrix-{str(basedate_test)}.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile, delimiter=',',
                            quotechar='"', quoting=csv.QUOTE_ALL)

    writer.writerow(["context"] + list(group_names))
    for i in range(rrmse_matrix.shape[0]):
        writer.writerow([context_names[i]] + list(rrmse_matrix[i,:]))

# %% [markdown]
# # CHECKPOINT

# %%
rrmse_df = pd.read_csv(f'./rrmse_matrix-{str(basedate_test)}.csv', sep=",")
rrmse_df = rrmse_df.set_index('context')
rrmse_df = rrmse_df.apply(lambda x: 10*x) # in csv values are not divided by 10 (to average)
rrmse_df.head()
# Out:
#                  food    nonfood     travel      money     beauty        fun  \
# context
# Ковид        1.751089  15.470560   4.462045   9.133985  11.998944   5.029132
# Белоруссия   1.806101  15.482166   4.918450   8.049400  12.149675   5.983808
# Украина      1.907988  16.502478   5.419877   8.605455  12.909760   5.584062
# Здоровье    16.069564  45.780992  14.642164  31.868226  28.701237  24.496522
# Спорт        2.863163  16.195755   4.959469   8.179589  11.194587   6.473788
#
#                health   dwelling     outfit       kids       misc    telecom  \
# context
# Ковид        2.671117   8.073889  19.784424  12.612385  11.412429   9.160033
# Белоруссия   3.240522  10.201673  22.336757  14.597558  13.017338  10.488661
# Украина      2.990722   8.593714  22.138010  16.481394  12.407752  12.190922
# Здоровье    40.844664  41.051848  32.726711  27.392624  15.715711  15.388530
# Спорт        6.275406  11.062542  27.007231  21.027380  12.814150   9.270597
#
# ...

# %% [markdown]
# # EXPERIMENT 0: prediction by all topics

# %%
cli_df = cli_dfs[0]

for add_exp in reversed(range(num_experiments)):
    start_test = basedate_test + timedelta(add_exp)
    cli_test = cli_df[cli_df.index.date >= start_test].copy()
    cli_train = cli_df[cli_df.index.date < start_test].copy()

    news_cur = news_df # all news
    
    news_test = news_cur[news_cur.index.date >= start_test].copy()
    news_train = news_cur[news_cur.index.date < start_test].copy()

    rrmse_array = []

    arimax = sm.tsa.statespace.SARIMAX(cli_train, \
                                    order=(7,1,7), \
                                    seasonal_order=(0,0,0,0), \
                                    exog = news_train, \
                                    freq='D', \
                                    enforce_stationarity=False, \
                                    enforce_invertibility=False).fit(disp=False)
    pred = arimax.predict(start_test, date(2020, 9, 30), exog=news_test)[1:]

    cur_pred = pd.DataFrame([pred, cli_test]).T.dropna()
    arr1 = (np.array(cur_pred['predicted_mean']) - np.array(cur_pred['trend']))**2
    arr2 = np.array(cur_pred['trend']).mean()
    rrmse = np.sqrt(arr1.sum()/(len(cur_pred) - 1)) / arr2
    rrmse_array.append(rrmse)

rrmse = np.array(rrmse_array).mean()

plt.figure(facecolor='white')
plt.clf()
plt.plot(cli_df)
plt.plot(pred)
plt.title(f"Category: food    Context: all topics    Total rRMSE: {rrmse*100:.2f}%")
plt.ylabel("Spendings, rub")
plt.xlabel("Date")
plt.legend(["Real", "Predicted"])
plt.savefig(f"./arimax_pics/all_food.png")
# Out:
# /home/dormant/.local/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/dormant/.local/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/dormant/.local/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/dormant/.local/lib/python3.10/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ...

# %% [markdown]
# # Setup

# %%
rrmse_df = rrmse_df.drop(columns=['money', 'remote', 'charity'])
rrmse_df = rrmse_df.drop(['Здоровье'])

# %%
plt.figure(facecolor='white')
plt.plot(rrmse_df['food'], linestyle="--", marker="o", label="food")
plt.plot(rrmse_df['outfit'], linestyle="--", marker="s", label="outfit")
plt.plot(rrmse_df['kids'], linestyle="--", marker="v", label="kids")
plt.plot(rrmse_df['dwelling'], linestyle="--", marker="^", label="dwelling")

plt.xticks(ticks=list(range(len(rrmse_df))), labels=[i+1 for i in range(len(rrmse_df))], \
          rotation=90)
plt.title('rRMSE of prediction based on context variables')
plt.ylabel('rRMSE of prediction, %')
plt.legend()
plt.savefig('./final_pics/variables.png', dpi=300)

# %%
error_means = rrmse_df.T.mean(axis=1)
labels = [f"{i}\n{rrmse_df.std()[i]:.2f}" for i in list(rrmse_df.columns)]

plt.figure(facecolor='white')
plt.grid(zorder=0)
plt.bar(labels, error_means, color="coral", zorder=10)
plt.title(f'Mean rRMSE of prediction and standard deviation\namong context variables based on category')
plt.ylabel('rRMSE of prediction, %')
plt.savefig('./final_pics/categories.png', dpi=300)

# %% [markdown]
# # EXPERIMENT 1: prediction of good categories

# %%
print(group_names, "\n")
print(context_names)
# Out:
# ['food' 'nonfood' 'travel' 'money' 'beauty' 'fun' 'health' 'dwelling'
#  'outfit' 'kids' 'misc' 'telecom' 'remote' 'charity']
#
# ['Ковид', 'Белоруссия', 'Украина', 'Здоровье', 'Спорт', 'Погода', 'Религия', 'Авиация', 'Путешествия', 'Метро', 'Телевидение', 'Инвестиции', 'Правительство', 'Индекс доступности недвижимости, СПБ', 'Индекс доступности недвижимости, Россия', 'Ключевая ставка ЦБ', 'Инфляция в процентах годовых', 'Курс доллара, руб', 'Средние ставки по ипотеке', 'Средние ставки по ипотеке, перв. рынок', 'Средние ставки по ипотеке, втор. рынок', 'Индекс потребительских цен', 'Индекс потребительских цен, продовольствие', 'Индекс потребительских цен, не продукты', 'Индекс потребительских цен, услуги', 'Безработица', 'ВВП относительно предыдущего года', 'Относительный ВВП за вычетом сезонных вкладов', 'ВВП в млрд. руб.', 'Covid-19 в РФ, всего заражений', 'Covid-19 в РФ, новых заражений', 'Covid-19 в РФ, всего смертей', 'Covid-19 в РФ, новых смертей']

# %% [markdown]
# Categories:
# - food (0)
# - travel (2)
# - fun (5)
# - health (6)

# %% [markdown]
# Cross-correlation analysis utility function:

# %%
def crosscorr(datax, datay, lag=0, wrap=False):
    """ Lag-N cross correlation. 
    lag : int, default 0
    datax, datay : pandas.Series objects of equal length
    
    Returns
    crosscorr : float
    """
    if wrap:
        shiftedy = datay.shift(lag)
        shiftedy.iloc[:lag] = datay.iloc[-lag:].values
        return datax.corr(shiftedy)
    else: 
        return datax.corr(datay.shift(lag))

# %% [markdown]
# ## food

# %%
var = 0
cli_df = cli_dfs[var]

rrmse_array = []

for add_exp in reversed(range(num_experiments)):
    start_test = basedate_test + timedelta(add_exp)

    cli_test = cli_df[cli_df.index.date >= start_test].copy()
    cli_train = cli_df[cli_df.index.date < start_test].copy()

    topics_choice = rrmse_df.nsmallest(5, 'food')
    col_list = list(topics_choice.index)
    news_cur = news_df[col_list]
    
    news_test = news_cur[news_cur.index.date >= start_test].copy()
    news_train = news_cur[news_cur.index.date < start_test].copy()


    arimax = sm.tsa.statespace.SARIMAX(cli_train, \
                                    order=(7,1,7), \
                                    seasonal_order=(0,0,0,0), \
                                    exog = news_train, \
                                    freq='D', \
                                    enforce_stationarity=False, \
                                    enforce_invertibility=False).fit(disp=False)
    pred = arimax.predict(start_test, date(2020, 9, 30), exog=news_test)[1:]

    cur_pred = pd.DataFrame([pred, cli_test]).T.dropna()
    arr1 = (np.array(cur_pred['predicted_mean']) - np.array(cur_pred['trend']))**2
    arr2 = np.array(cur_pred['trend']).mean()
    rrmse = np.sqrt(arr1.sum()/(len(cur_pred) - 1)) / arr2
    rrmse_array.append(rrmse)

print(col_list)
rrmse = np.array(rrmse_array).mean()

plt.figure(facecolor='white')
plt.clf()
plt.plot(cli_df)
plt.plot(pred)
plt.title(f"Category: food    Context: 5 best topics    Total rRMSE: {rrmse*100:.2f}%")
plt.ylabel("Spendings, rub")
plt.xlabel("Date")
plt.legend(["Real", "Predicted"])
plt.savefig(f"./arimax_pics/good_food.png", dpi=300)
# Out:
# ['Религия', 'Средние ставки по ипотеке, втор. рынок', 'Авиация', 'Инвестиции', 'Средние ставки по ипотеке']

# %%
max_lag = 122
corr_table = []
corr_groups = set()
corr_vars = set()

# %%
corr_groups.add(var)

plt.rcParams['figure.figsize'] = [15, 45]
plt.figure(facecolor='white')
for num, item in enumerate(col_list):
    plt.subplot(len(col_list), 1, num+1)
    t1 = cli_df[3:-3]
    t2 = news_df[item][3:-3]
    
    rs = [crosscorr(t1, t2, lag) for lag in range(0,int(max_lag+1))]
    offset = np.floor(len(rs)/2)-np.argmax(rs)

    corr_vars.add(item)
    plt.plot(rs)
    if np.abs(np.max(rs)) >= np.abs(np.min(rs)):
        corr_table.append(f'{group_names[var]}, {item}: {np.argmax(rs)}, {np.max(rs):.2f}')
        plt.axvline(np.argmax(rs), color='coral', linestyle='--', label='Max + corr')
    else:
        corr_table.append(f'{group_names[var]}, {item}: {np.argmin(rs)}, {np.min(rs):.2f}')
        plt.axvline(np.argmin(rs), color='cornflowerblue', linestyle='--', label='Max - corr')
    
    plt.title(f'"{item}" cross-correlation with category "{group_names[var]}"')
    plt.xlabel('Offset')
    plt.ylabel('Pearson r')
    plt.xticks(list(range(0, len(t1), 5)), labels=list(range(0, len(t1), 5)), rotation=90)
    plt.xlim(right=(max_lag + 10))
    plt.legend()
    
plt.rcParams['figure.figsize'] = [15, 7.5]

# %% [markdown]
# ## travel

# %%
var = 2
cli_df = cli_dfs[var]

rrmse_array = []

for add_exp in reversed(range(num_experiments)):
    start_test = basedate_test + timedelta(add_exp)
    
    cli_test = cli_df[cli_df.index.date >= start_test].copy()
    cli_train = cli_df[cli_df.index.date < start_test].copy()

    topics_choice = rrmse_df.nsmallest(5, 'travel')
    col_list = list(topics_choice.index)
    news_cur = news_df[col_list]
    
    news_test = news_cur[news_cur.index.date >= start_test].copy()
    news_train = news_cur[news_cur.index.date < start_test].copy()

    arimax = sm.tsa.statespace.SARIMAX(cli_train, \
                                    order=(7,1,7), \
                                    seasonal_order=(0,0,0,0), \
                                    exog = news_train, \
                                    freq='D', \
                                    enforce_stationarity=False, \
                                    enforce_invertibility=False).fit(disp=False)
    pred = arimax.predict(start_test, date(2020, 9, 30), exog=news_test)[1:]

    cur_pred = pd.DataFrame([pred, cli_test]).T.dropna()
    arr1 = (np.array(cur_pred['predicted_mean']) - np.array(cur_pred['trend']))**2
    arr2 = np.array(cur_pred['trend']).mean()
    rrmse = np.sqrt(arr1.sum()/(len(cur_pred) - 1)) / arr2
    rrmse_array.append(rrmse)

print(col_list)
rrmse = np.array(rrmse_array).mean()
    
plt.figure(facecolor='white')
plt.clf()
plt.plot(cli_df)
plt.plot(pred)
plt.title(f"Category: travel    Context: 5 best topics    Total rRMSE: {rrmse*100:.2f}%")
plt.ylabel("Spendings, rub")
plt.xlabel("Date")
plt.legend(["Real", "Predicted"])
plt.savefig(f"./arimax_pics/good_travel.png", dpi=300)
# Out:
# ['Метро', 'Безработица', 'Ковид', 'Ключевая ставка ЦБ', 'Курс доллара, руб']

# %%
corr_groups.add(var)

plt.rcParams['figure.figsize'] = [15, 45]
plt.figure(facecolor='white')
for num, item in enumerate(col_list):
    plt.subplot(len(col_list), 1, num+1)
    t1 = cli_df[3:-3]
    t2 = news_df[item][3:-3]
    
    rs = [crosscorr(t1, t2, lag) for lag in range(0,int(max_lag+1))]
    offset = np.floor(len(rs)/2)-np.argmax(rs)

    corr_vars.add(item)
    plt.plot(rs)
    if np.abs(np.max(rs)) >= np.abs(np.min(rs)):
        corr_table.append(f'{group_names[var]}, {item}: {np.argmax(rs)}, {np.max(rs):.2f}')
        plt.axvline(np.argmax(rs), color='coral', linestyle='--', label='Max + corr')
    else:
        corr_table.append(f'{group_names[var]}, {item}: {np.argmin(rs)}, {np.min(rs):.2f}')
        plt.axvline(np.argmin(rs), color='cornflowerblue', linestyle='--', label='Max - corr')
    
    plt.title(f'"{item}" cross-correlation with category "{group_names[var]}"')
    plt.xlabel('Offset')
    plt.ylabel('Pearson r')
    plt.xticks(list(range(0, len(t1), 5)), labels=list(range(0, len(t1), 5)), rotation=90)
    plt.xlim(right=(max_lag + 10))
    plt.legend()
    
plt.rcParams['figure.figsize'] = [15, 7.5]

# %% [markdown]
# ## fun

# %%
var = 5
cli_df = cli_dfs[var]

rrmse_array = []

for add_exp in reversed(range(num_experiments)):
    start_test = basedate_test + timedelta(add_exp)

    cli_test = cli_df[cli_df.index.date >= start_test].copy()
    cli_train = cli_df[cli_df.index.date < start_test].copy()

    topics_choice = rrmse_df.nsmallest(5, 'fun')
    col_list = list(topics_choice.index)
    news_cur = news_df[col_list]
    
    news_test = news_cur[news_cur.index.date >= start_test].copy()
    news_train = news_cur[news_cur.index.date < start_test].copy()

    arimax = sm.tsa.statespace.SARIMAX(cli_train, \
                                    order=(7,1,7), \
                                    seasonal_order=(0,0,0,0), \
                                    exog = news_train, \
                                    freq='D', \
                                    enforce_stationarity=False, \
                                    enforce_invertibility=False).fit(disp=False)
    pred = arimax.predict(start_test, date(2020, 9, 30), exog=news_test)[1:]

    cur_pred = pd.DataFrame([pred, cli_test]).T.dropna()
    arr1 = (np.array(cur_pred['predicted_mean']) - np.array(cur_pred['trend']))**2
    arr2 = np.array(cur_pred['trend']).mean()
    rrmse = np.sqrt(arr1.sum()/(len(cur_pred) - 1)) / arr2
    rrmse_array.append(rrmse)

print(col_list)
rrmse = np.array(rrmse_array).mean()
    
plt.figure(facecolor='white')
plt.clf()
plt.plot(cli_df)
plt.plot(pred)
plt.title(f"Category: fun    Context: 5 best topics    Total rRMSE: {rrmse*100:.2f}%")
plt.ylabel("Spendings, rub")
plt.xlabel("Date")
plt.legend(["Real", "Predicted"])
plt.savefig(f"./arimax_pics/good_fun.png", dpi=300)
# Out:
# ['Covid-19 в РФ, всего заражений', 'Covid-19 в РФ, всего смертей', 'Путешествия', 'Инфляция в процентах годовых', 'ВВП в млрд. руб.']

# %%
corr_groups.add(var)

plt.rcParams['figure.figsize'] = [15, 45]
plt.figure(facecolor='white')
for num, item in enumerate(col_list):
    plt.subplot(len(col_list), 1, num+1)
    t1 = cli_df[3:-3]
    t2 = news_df[item][3:-3]
    
    rs = [crosscorr(t1, t2, lag) for lag in range(0,int(max_lag+1))]
    offset = np.floor(len(rs)/2)-np.argmax(rs)

    corr_vars.add(item)
    plt.plot(rs)
    if np.abs(np.max(rs)) >= np.abs(np.min(rs)):
        corr_table.append(f'{group_names[var]}, {item}: {np.argmax(rs)}, {np.max(rs):.2f}')
        plt.axvline(np.argmax(rs), color='coral', linestyle='--', label='Max + corr')
    else:
        corr_table.append(f'{group_names[var]}, {item}: {np.argmin(rs)}, {np.min(rs):.2f}')
        plt.axvline(np.argmin(rs), color='cornflowerblue', linestyle='--', label='Max - corr')
    
    plt.title(f'"{item}" cross-correlation with category "{group_names[var]}"')
    plt.xlabel('Offset')
    plt.ylabel('Pearson r')
    plt.xticks(list(range(0, len(t1), 5)), labels=list(range(0, len(t1), 5)), rotation=90)
    plt.xlim(right=(max_lag + 10))
    plt.legend()
    
plt.rcParams['figure.figsize'] = [15, 7.5]

# %% [markdown]
# ## health

# %%
var = 6
cli_df = cli_dfs[var]

rrmse_array = []

for add_exp in reversed(range(num_experiments)):
    start_test = basedate_test + timedelta(add_exp)
    
    cli_test = cli_df[cli_df.index.date >= start_test].copy()
    cli_train = cli_df[cli_df.index.date < start_test].copy()

    topics_choice = rrmse_df.nsmallest(5, 'health')
    col_list = list(topics_choice.index)
    news_cur = news_df[col_list]
    
    news_test = news_cur[news_cur.index.date >= start_test].copy()
    news_train = news_cur[news_cur.index.date < start_test].copy()

    arimax = sm.tsa.statespace.SARIMAX(cli_train, \
                                    order=(7,1,7), \
                                    seasonal_order=(0,0,0,0), \
                                    exog = news_train, \
                                    freq='D', \
                                    enforce_stationarity=False, \
                                    enforce_invertibility=False).fit(disp=False)
    pred = arimax.predict(start_test, date(2020, 9, 30), exog=news_test)[1:]

    cur_pred = pd.DataFrame([pred, cli_test]).T.dropna()
    arr1 = (np.array(cur_pred['predicted_mean']) - np.array(cur_pred['trend']))**2
    arr2 = np.array(cur_pred['trend']).mean()
    rrmse = np.sqrt(arr1.sum()/(len(cur_pred) - 1)) / arr2
    rrmse_array.append(rrmse)

print(col_list)
rrmse = np.array(rrmse_array).mean()
    
plt.figure(facecolor='white')
plt.clf()
plt.plot(cli_df)
plt.plot(pred)
plt.title(f"Category: health    Context: 5 best topics    Total rRMSE: {rrmse*100:.2f}%")
plt.ylabel("Spendings, rub")
plt.xlabel("Date")
plt.legend(["Real", "Predicted"])
plt.savefig(f"./arimax_pics/good_health.png", dpi=300)
# Out:
# ['Индекс доступности недвижимости, Россия', 'Индекс доступности недвижимости, СПБ', 'Ковид', 'ВВП в млрд. руб.', 'Covid-19 в РФ, новых заражений']

# %%
corr_groups.add(var)

plt.rcParams['figure.figsize'] = [15, 45]
plt.figure(facecolor='white')
for num, item in enumerate(col_list):
    plt.subplot(len(col_list), 1, num+1)
    t1 = cli_df[3:-3]
    t2 = news_df[item][3:-3]
    
    rs = [crosscorr(t1, t2, lag) for lag in range(0,int(max_lag+1))]
    offset = np.floor(len(rs)/2)-np.argmax(rs)

    corr_vars.add(item)
    plt.plot(rs)
    if np.abs(np.max(rs)) >= np.abs(np.min(rs)):
        corr_table.append(f'{group_names[var]}, {item}: {np.argmax(rs)}, {np.max(rs):.2f}')
        plt.axvline(np.argmax(rs), color='coral', linestyle='--', label='Max + corr')
    else:
        corr_table.append(f'{group_names[var]}, {item}: {np.argmin(rs)}, {np.min(rs):.2f}')
        plt.axvline(np.argmin(rs), color='cornflowerblue', linestyle='--', label='Max - corr')
    
    plt.title(f'"{item}" cross-correlation with category "{group_names[var]}"')
    plt.xlabel('Offset')
    plt.ylabel('Pearson r')
    plt.xticks(list(range(0, len(t1), 5)), labels=list(range(0, len(t1), 5)), rotation=90)
    plt.xlim(right=(max_lag + 10))
    plt.legend()
    
plt.rcParams['figure.figsize'] = [15, 7.5]

# %% [markdown]
# # EXPERIMENT 2: topic addition for better prognosis

# %% [markdown]
# Cross correlation utility function:

# %%
print(group_names, "\n")
print(context_names)
# Out:
# ['food' 'nonfood' 'travel' 'money' 'beauty' 'fun' 'health' 'dwelling'
#  'outfit' 'kids' 'misc' 'telecom' 'remote' 'charity']
#
# ['Ковид', 'Белоруссия', 'Украина', 'Здоровье', 'Спорт', 'Погода', 'Религия', 'Авиация', 'Путешествия', 'Метро', 'Телевидение', 'Инвестиции', 'Правительство', 'Индекс доступности недвижимости, СПБ', 'Индекс доступности недвижимости, Россия', 'Ключевая ставка ЦБ', 'Инфляция в процентах годовых', 'Курс доллара, руб', 'Средние ставки по ипотеке', 'Средние ставки по ипотеке, перв. рынок', 'Средние ставки по ипотеке, втор. рынок', 'Индекс потребительских цен', 'Индекс потребительских цен, продовольствие', 'Индекс потребительских цен, не продукты', 'Индекс потребительских цен, услуги', 'Безработица', 'ВВП относительно предыдущего года', 'Относительный ВВП за вычетом сезонных вкладов', 'ВВП в млрд. руб.', 'Covid-19 в РФ, всего заражений', 'Covid-19 в РФ, новых заражений', 'Covid-19 в РФ, всего смертей', 'Covid-19 в РФ, новых смертей']

# %% [markdown]
# Topics:
# - beauty (4)
# - kids (9)

# %% [markdown]
# ## beauty

# %%
var = 4
cli_df = cli_dfs[var]

rrmse_array1 = []
rrmse_array2 = []

for add_exp in range(num_experiments):
    start_test = basedate_test + timedelta(add_exp)
    
    cli_test = cli_df[cli_df.index.date >= start_test].copy()
    cli_train = cli_df[cli_df.index.date < start_test].copy()

    topics_choice = rrmse_df[(rrmse_df['beauty'] < 15) & (rrmse_df['beauty'] >= 7.5)]
    col_list = list(topics_choice.index)
    news_cur = news_df[col_list]
    
    news_test = news_cur[news_cur.index.date >= start_test].copy()
    news_train = news_cur[news_cur.index.date < start_test].copy()

    arimax = sm.tsa.statespace.SARIMAX(cli_train, \
                                    order=(7,1,7), \
                                    seasonal_order=(0,0,0,0), \
                                    exog = news_train, \
                                    freq='D', \
                                    enforce_stationarity=False, \
                                    enforce_invertibility=False).fit(disp=False)
    pred1 = arimax.predict(start_test, date(2020, 9, 30), exog=news_test)[1:]

    cur_pred = pd.DataFrame([pred1, cli_test]).T.dropna()
    arr1 = (np.array(cur_pred['predicted_mean']) - np.array(cur_pred['trend']))**2
    arr2 = np.array(cur_pred['trend']).mean()
    rrmse1 = np.sqrt(arr1.sum()/(len(cur_pred) - 1)) / arr2
    rrmse_array1.append(rrmse1)

    # Added topics

    topics_choice = rrmse_df[rrmse_df['beauty'] < 7.5]
    col_list = list(topics_choice.index)
    news_cur = news_df[col_list]
    
    news_test = news_cur[news_cur.index.date >= start_test].copy()
    news_train = news_cur[news_cur.index.date < start_test].copy()

    arimax = sm.tsa.statespace.SARIMAX(cli_train, \
                                    order=(7,1,7), \
                                    seasonal_order=(0,0,0,0), \
                                    exog = news_train, \
                                    freq='D', \
                                    enforce_stationarity=False, \
                                    enforce_invertibility=False).fit(disp=False)
    pred2 = arimax.predict(start_test, date(2020, 9, 30), exog=news_test)[1:]

    cur_pred = pd.DataFrame([pred2, cli_test]).T.dropna()
    arr1 = (np.array(cur_pred['predicted_mean']) - np.array(cur_pred['trend']))**2
    arr2 = np.array(cur_pred['trend']).mean()
    rrmse2 = np.sqrt(arr1.sum()/(len(cur_pred) - 1)) / arr2
    rrmse_array2.append(rrmse2)

print(col_list)
rrmse1 = np.array(rrmse_array1).mean()
rrmse2 = np.array(rrmse_array2).mean()
    
plt.figure(facecolor='white')
plt.clf()
plt.plot(cli_df, label="Real")
plt.plot(pred1, label='Predicted')
plt.plot(pred2, label='\n'.join(list(col_list)))
plt.title(f"Category: beauty    Context: 7.5-15% rRMSE\nTotal rRMSE: from {rrmse1*100:.2f}% to {rrmse2*100:.2f}%")
plt.ylabel("Spendings, rub")
plt.xlabel("Date")
plt.legend()
plt.savefig(f"./arimax_pics/add_beauty.png")
# Out:
# ['Индекс потребительских цен', 'Индекс потребительских цен, продовольствие']

# %%
corr_groups.add(var)

plt.rcParams['figure.figsize'] = [15, 18]
plt.figure(facecolor='white')
for num, item in enumerate(col_list):
    plt.subplot(len(col_list), 1, num+1)
    t1 = cli_df[3:-3]
    t2 = news_df[item][3:-3]
    
    rs = [crosscorr(t1, t2, lag) for lag in range(0,int(max_lag+1))]
    offset = np.floor(len(rs)/2)-np.argmax(rs)

    corr_vars.add(item)
    plt.plot(rs)
    if np.abs(np.max(rs)) >= np.abs(np.min(rs)):
        corr_table.append(f'{group_names[var]}, {item}: {np.argmax(rs)}, {np.max(rs):.2f}')
        plt.axvline(np.argmax(rs), color='coral', linestyle='--', label='Max + corr')
    else:
        corr_table.append(f'{group_names[var]}, {item}: {np.argmin(rs)}, {np.min(rs):.2f}')
        plt.axvline(np.argmin(rs), color='cornflowerblue', linestyle='--', label='Max - corr')
    
    plt.title(f'"{item}" cross-correlation with category "{group_names[var]}"')
    plt.xlabel('Offset')
    plt.ylabel('Pearson r')
    plt.xticks(list(range(0, len(t1), 5)), labels=list(range(0, len(t1), 5)), rotation=90)
    plt.xlim(right=(max_lag + 10))
    plt.legend()
    
plt.rcParams['figure.figsize'] = [15, 7.5]

# %% [markdown]
# ## kids

# %%
var = 9
cli_df = cli_dfs[var]

rrmse_array1 = []
rrmse_array2 = []

for add_exp in range(num_experiments):
    start_test = basedate_test + timedelta(add_exp)
    
    cli_test = cli_df[cli_df.index.date >= start_test].copy()
    cli_train = cli_df[cli_df.index.date < start_test].copy()

    topics_choice = rrmse_df[(rrmse_df['kids'] < 23) & (rrmse_df['kids'] >= 10)]
    col_list = list(topics_choice.index)
    news_cur = news_df[col_list]
    
    news_test = news_cur[news_cur.index.date >= start_test].copy()
    news_train = news_cur[news_cur.index.date < start_test].copy()

    arimax = sm.tsa.statespace.SARIMAX(cli_train, \
                                    order=(7,1,7), \
                                    seasonal_order=(0,0,0,0), \
                                    exog = news_train, \
                                    freq='D', \
                                    enforce_stationarity=False, \
                                    enforce_invertibility=False).fit(disp=False)
    pred1 = arimax.predict(start_test, date(2020, 9, 30), exog=news_test)[1:]

    cur_pred = pd.DataFrame([pred1, cli_test]).T.dropna()
    arr1 = (np.array(cur_pred['predicted_mean']) - np.array(cur_pred['trend']))**2
    arr2 = np.array(cur_pred['trend']).mean()
    rrmse1 = np.sqrt(arr1.sum()/(len(cur_pred) - 1)) / arr2
    rrmse_array1.append(rrmse1)

# Added topics

    topics_choice = rrmse_df[rrmse_df['kids'] < 10]
    col_list = list(topics_choice.index)
    news_cur = news_df[col_list]
    
    news_test = news_cur[news_cur.index.date >= start_test].copy()
    news_train = news_cur[news_cur.index.date < start_test].copy()

    arimax = sm.tsa.statespace.SARIMAX(cli_train, \
                                    order=(7,1,7), \
                                    seasonal_order=(0,0,0,0), \
                                    exog = news_train, \
                                    freq='D', \
                                    enforce_stationarity=False, \
                                    enforce_invertibility=False).fit(disp=False)
    pred2 = arimax.predict(start_test, date(2020, 9, 30), exog=news_test)[1:]

    cur_pred = pd.DataFrame([pred2, cli_test]).T.dropna()
    arr1 = (np.array(cur_pred['predicted_mean']) - np.array(cur_pred['trend']))**2
    arr2 = np.array(cur_pred['trend']).mean()
    rrmse2 = np.sqrt(arr1.sum()/(len(cur_pred) - 1)) / arr2
    rrmse_array2.append(rrmse2)

print(col_list)
rrmse1 = np.array(rrmse_array1).mean()
rrmse2 = np.array(rrmse_array2).mean()
    
plt.figure(facecolor='white')
plt.clf()
plt.plot(cli_df, label="Real")
plt.plot(pred1, label='Predicted')
plt.plot(pred2, label="\n".join(list(col_list)))
plt.title(f"Category: kids    Context: 10-23% rRMSE\nTotal rRMSE: from {rrmse1*100:.2f}% to {rrmse2*100:.2f}%")
plt.ylabel("Spendings, rub")
plt.xlabel("Date")
plt.legend()
plt.savefig(f"./arimax_pics/add_kids.png")
# Out:
# ['Индекс потребительских цен', 'Индекс потребительских цен, продовольствие', 'Индекс потребительских цен, услуги']

# %%
corr_groups.add(var)

plt.rcParams['figure.figsize'] = [15, 25]
plt.figure(facecolor='white')
for num, item in enumerate(col_list):
    plt.subplot(len(col_list), 1, num+1)
    t1 = cli_df[3:-3]
    t2 = news_df[item][3:-3]
    
    rs = [crosscorr(t1, t2, lag) for lag in range(0,int(max_lag+1))]
    offset = np.floor(len(rs)/2)-np.argmax(rs)

    corr_vars.add(item)
    plt.plot(rs)
    if np.abs(np.max(rs)) >= np.abs(np.min(rs)):
        corr_table.append(f'{group_names[var]}, {item}: {np.argmax(rs)}, {np.max(rs):.2f}')
        plt.axvline(np.argmax(rs), color='coral', linestyle='--', label='Max + corr')
    else:
        corr_table.append(f'{group_names[var]}, {item}: {np.argmin(rs)}, {np.min(rs):.2f}')
        plt.axvline(np.argmin(rs), color='cornflowerblue', linestyle='--', label='Max - corr')
    
    plt.title(f'"{item}" cross-correlation with category "{group_names[var]}"')
    plt.xlabel('Offset')
    plt.ylabel('Pearson r')
    plt.xticks(list(range(0, len(t1), 5)), labels=list(range(0, len(t1), 5)), rotation=90)
    plt.xlim(right=(max_lag + 10))
    plt.legend()
    
plt.rcParams['figure.figsize'] = [15, 7.5]

# %% [markdown]
# Cross-correlations for the table:

# %%
for item in corr_table:
    print(item)
# Out:
# food, Религия: 122, 0.85
# food, Средние ставки по ипотеке, втор. рынок: 113, 0.80
# food, Авиация: 119, -0.52
# food, Инвестиции: 39, 0.61
# food, Средние ставки по ипотеке: 111, 0.81
# travel, Метро: 0, 0.67
# travel, Безработица: 22, 0.94
# travel, Ковид: 21, -0.93
# travel, Ключевая ставка ЦБ: 18, -0.95
# travel, Курс доллара, руб: 49, -0.77
# fun, Covid-19 в РФ, всего заражений: 0, 0.89
# fun, Covid-19 в РФ, всего смертей: 0, 0.87
# fun, Путешествия: 35, 0.54
# fun, Инфляция в процентах годовых: 0, 0.85
# fun, ВВП в млрд. руб.: 0, 0.83
# health, Индекс доступности недвижимости, Россия: 0, 0.77
# health, Индекс доступности недвижимости, СПБ: 0, 0.68
# health, Ковид: 0, -0.81
# health, ВВП в млрд. руб.: 0, 0.69
# health, Covid-19 в РФ, новых заражений: 90, -0.60
# beauty, Индекс потребительских цен: 86, -0.80
# beauty, Индекс потребительских цен, продовольствие: 24, -0.84
# kids, Индекс потребительских цен: 0, -0.75
# kids, Индекс потребительских цен, продовольствие: 13, -0.74
# ...

# %%
corr_combs = list(itertools.product(corr_groups, corr_vars))
print(f'Table size: {int(len(corr_combs) / len(corr_groups))} x {len(corr_groups)}')
print(corr_combs[0])

corr_groups_dict = {item: num for num, item in enumerate(list(corr_groups))}
corr_vars_dict = {item: num for num, item in enumerate(list(corr_vars))}
# Out:
# Table size: 21 x 6
# (0, 'Безработица')

# %%
corr_table_np = np.zeros((int(len(corr_combs) / len(corr_groups)), len(corr_groups)), \
                         dtype=str)
corr_table = [list(i) for i in corr_table_np]

for num, comb in enumerate(corr_combs):
    cli_df = cli_dfs[comb[0]]
    t1 = cli_df[3:-3]
    t2 = news_df[comb[1]][3:-3]
    rs = [crosscorr(t1, t2, lag) for lag in range(0,int(max_lag+1))]
    if num == 0:
        plt.plot(rs)
    #offset = np.floor(len(rs)/2)-np.argmax(rs)

    if np.abs(np.max(rs)) >= np.abs(np.min(rs)):
        ans = f'{np.argmax(rs)}, {np.max(rs):.2f}'
    else:
        ans = f'{np.argmin(rs)}, {np.min(rs):.2f}'
    
    corr_table[corr_vars_dict[comb[1]]][corr_groups_dict[comb[0]]] = ans

# %%
corr_df = pd.DataFrame(data=np.array(corr_table), \
                      index=list(corr_vars_dict), \
                      columns=[group_names[i] for i in list(corr_groups)])

corr_df
# Out:
#                                                   food      travel  \
# Безработица                                 113, -0.81    22, 0.94
# Covid-19 в РФ, всего смертей                 95, -0.80     0, 0.89
# Метро                                        63, -0.63     0, 0.67
# Индекс доступности недвижимости, Россия     102, -0.82     0, 0.93
# Ключевая ставка ЦБ                           103, 0.82   18, -0.95
# Ковид                                         97, 0.81   21, -0.93
# Путешествия                                  94, -0.76  122, -0.66
# Инвестиции                                    39, 0.61   117, 0.45
# ВВП в млрд. руб.                             83, -0.81     0, 0.82
# Авиация                                     119, -0.52  119, -0.78
# Средние ставки по ипотеке, втор. рынок       113, 0.80    0, -0.89
# Курс доллара, руб                             96, 0.80   49, -0.77
# Индекс доступности недвижимости, СПБ        122, -0.72     0, 0.88
# ...
